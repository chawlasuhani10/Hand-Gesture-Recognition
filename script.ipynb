# %%
import librosa

# %%
import librosa.display

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
audio_file = 'hw1.wav'

# %%
y, sr = librosa.load(audio_file)
D = librosa.amplitude_to_db(librosa.stft(y), ref = np.max)
# Out:
# C:\Users\chawl\AppData\Local\Temp\ipykernel_46044\868560152.py:2: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   D = librosa.amplitude_to_db(librosa.stft(y), ref = np.max)

# %%
plt.figure(figsize = (10,6))
librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log', cmap ='hot')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram of University of Massachusetts')
plt.savefig('spectrogram.png')  # Save the spectrogram as an image
plt.show()
